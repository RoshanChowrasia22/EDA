# %%
import kagglehub
import os
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Download latest version
path = kagglehub.dataset_download("kashnitsky/mlcourse")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Roshan\.cache\kagglehub\datasets\kashnitsky\mlcourse\versions\17

# %%
PATH_TO_DATA=r'C:\Users\Roshan\.cache\kagglehub\datasets\kashnitsky\mlcourse\versions\17'
folders=os.listdir(path=PATH_TO_DATA)
print(folders,len(folders))
# Out:
# ['accidental-deaths-in-usa-monthly.csv', 'ads.csv', 'ads_hour.csv', 'adult.data.csv', 'adult_test.csv', 'adult_train.csv', 'affairs.csv', 'beauty.csv', 'credit_scoring_sample.csv', 'currency.csv', 'flight_delays_test.csv', 'flight_delays_train.csv', 'hostel_factors.csv', 'medium_posts.csv', 'microchip_tests.txt', 'mlbootcamp5_train.csv', 'samsung_test.txt', 'samsung_test_labels.txt', 'samsung_train.txt', 'samsung_train_labels.txt', 'site_dic.pkl', 'telecom_churn.csv', 'titanic_test.csv', 'titanic_train.csv', 'video_games_sales.csv', 'websites_test_sessions.csv', 'websites_train_sessions.csv', 'weights_heights.csv', 'wiki_machine_learning.csv', 'winequality-white.csv'] 30

# %%
Path_to_csv_file=os.path.join(PATH_TO_DATA,'telecom_churn.csv')
dataframe=pd.read_csv(Path_to_csv_file)
dataframe.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# ### We get the columns and size of dataframe

# %%
dataframe.columns,dataframe.__len__(),dataframe.shape
# Out:
# (Index(['State', 'Account length', 'Area code', 'International plan',
#         'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#         'Total day calls', 'Total day charge', 'Total eve minutes',
#         'Total eve calls', 'Total eve charge', 'Total night minutes',
#         'Total night calls', 'Total night charge', 'Total intl minutes',
#         'Total intl calls', 'Total intl charge', 'Customer service calls',
#         'Churn'],
#        dtype='object'),
#  3333,
#  (3333, 20))

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
dataframe['Churn']=dataframe['Churn'].astype("int64")
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
dataframe.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
dataframe.describe(include=["object","bool","int64","float64"])
# Out:
#        State  Account length    Area code International plan Voice mail plan  \
# count   3333     3333.000000  3333.000000               3333            3333
# unique    51             NaN          NaN                  2               2
# top       WV             NaN          NaN                 No              No
# freq     106             NaN          NaN               3010            2411
# mean     NaN      101.064806   437.182418                NaN             NaN
# std      NaN       39.822106    42.371290                NaN             NaN
# min      NaN        1.000000   408.000000                NaN             NaN
# 25%      NaN       74.000000   408.000000                NaN             NaN
# 50%      NaN      101.000000   415.000000                NaN             NaN
# 75%      NaN      127.000000   510.000000                NaN             NaN
# max      NaN      243.000000   510.000000                NaN             NaN
#
# ...

# %%
dataframe['Churn'].value_counts(normalize=True)
# Out:
# Churn
# 0    0.855086
# 1    0.144914
# Name: proportion, dtype: float64

# %%
dataframe.sort_values(by=['Total day charge',"Churn"], ascending=[False,True])
dataframe.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
# Churn rate
dataframe['Churn'].mean()
# Out:
# np.float64(0.14491449144914492)

# %%
dataframe[dataframe['Churn']==1].describe(include=["object","int64","float64"])
# Out:
#        State  Account length   Area code International plan Voice mail plan  \
# count    483      483.000000  483.000000                483             483
# unique    51             NaN         NaN                  2               2
# top       NJ             NaN         NaN                 No              No
# freq      18             NaN         NaN                346             403
# mean     NaN      102.664596  437.817805                NaN             NaN
# std      NaN       39.467820   42.792270                NaN             NaN
# min      NaN        1.000000  408.000000                NaN             NaN
# 25%      NaN       76.000000  408.000000                NaN             NaN
# 50%      NaN      103.000000  415.000000                NaN             NaN
# 75%      NaN      127.000000  510.000000                NaN             NaN
# max      NaN      225.000000  510.000000                NaN             NaN
#
# ...

# %%
dataframe[dataframe['Churn']==1]['Total day minutes'].mean()
# Out:
# np.float64(206.91407867494823)

# %%
dataframe.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
dataframe['International plan'].value_counts()
# Out:
# International plan
# No     3010
# Yes     323
# Name: count, dtype: int64

# %%
dataframe[(dataframe['Churn']==0) & (dataframe['International plan']=='No')]['Total intl minutes'].describe()
# Out:
# count    2664.000000
# mean       10.185473
# std         2.820070
# min         0.000000
# 25%         8.400000
# 50%        10.200000
# 75%        12.100000
# max        18.900000
# Name: Total intl minutes, dtype: float64

# %%
# Indexing by column name
dataframe.loc[0:5,"State":"International plan"]
# Out:
#   State  Account length  Area code International plan
# 0    KS             128        415                 No
# 1    OH             107        415                 No
# 2    NJ             137        415                 No
# 3    OH              84        408                Yes
# 4    OK              75        415                Yes
# 5    AL             118        510                Yes

# %%
# indexing by index number
dataframe.iloc[0:5,0:4]
# Out:
#   State  Account length  Area code International plan
# 0    KS             128        415                 No
# 1    OH             107        415                 No
# 2    NJ             137        415                 No
# 3    OH              84        408                Yes
# 4    OK              75        415                Yes

# %%
dataframe[-1:]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3332             39.85              265.9               82              22.6
#
#       Total night minutes  Total night calls  Total night charge  \
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3332                13.7                 4                3.7
#
#       Customer service calls  Churn
# 3332                       0      0

# %% [markdown]
# # To apply functions to each column, use apply():

# %%
dataframe.apply(np.max)
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes       395.0
# Total night calls           175
# Total night charge        17.77
# Total intl minutes         20.0
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                         1
# dtype: object

# %% [markdown]
# ### apply

# %%
dataframe[dataframe['State'].apply(lambda state: state[0]=='W')]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 9       WV             141        415                Yes             Yes
# 26      WY              57        408                 No             Yes
# 44      WI              64        510                 No              No
# 49      WY              97        415                 No             Yes
# 54      WY              87        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3278    WI              87        415                 No              No
# 3303    WI             114        415                 No             Yes
# 3319    WY              89        415                 No              No
# 3324    WV             159        415                 No              No
# 3329    WV              68        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
dataframe['Price']= '$'+dataframe['Total night charge'].astype(str)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
dataframe.head(10)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# ...

# %%
dataframe['Price']=dataframe['Price'].apply(lambda price: float(price[1:]))

# %%
dataframe.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %% [markdown]
# ### The map method can be used to replace values in a column by passing a dictionary of the form {old_value: new_value} as its argument:

# %%
d={"No":False,"Yes":True}
if dataframe['International plan'].unique().tolist() not in [[True,False],[False,True]]:
    dataframe['International plan']=dataframe['International plan'].map(d)
dataframe.head(5)
# Out:
#   State  Account length  Area code  International plan Voice mail plan  \
# 0    KS             128        415               False             Yes
# 1    OH             107        415               False             Yes
# 2    NJ             137        415               False              No
# 3    OH              84        408                True              No
# 4    OK              75        415                True              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %%
v=dataframe['International plan'].value_counts()

# %%
for i in v:
    print(i,v.index.to_list())
# Out:
# 3010 [False, True]
# 323 [False, True]

# %%
dataframe["Voice mail plan"]=dataframe["Voice mail plan"].map(d)
dataframe.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %%
dataframe.sort_values(by='Number vmail messages',ascending=False,inplace=True)

# %%
dataframe.head(10)
# Out:
#      State  Account length  Area code  International plan  Voice mail plan  \
# 845     FL             144        415               False             True
# 2716    WV             137        510               False             True
# 2887    OR             134        415               False             True
# 1596    AR              63        510               False             True
# 277     SD             144        408               False             True
# 268     MO              64        510               False             True
# 1797    WV              92        415               False             True
# 1441    NC             172        408               False             True
# 3154    CT              73        415               False             True
# 2608    IN              81        408               False             True
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 845                      51              283.9               98
# ...

# %% [markdown]
# ### group by
# #### df.groupby(by=grouping_columns)[columnstoshow].function()

# %%
columns_to_show=['Total day minutes','Total eve minutes','Total night minutes']
dataframe.groupby(by='Churn')[columns_to_show].describe(percentiles=[])
# Out:
#       Total day minutes                                            \
#                   count        mean        std  min    50%    max
# Churn
# 0                2850.0  175.175754  50.181655  0.0  177.2  315.6
# 1                 483.0  206.914079  68.997792  0.0  217.6  350.8
#
#       Total eve minutes                                             \
#                   count        mean        std   min    50%    max
# Churn
# 0                2850.0  199.043298  50.292175   0.0  199.6  361.8
# 1                 483.0  212.410145  51.728910  70.9  211.3  363.7
#
#       Total night minutes
#                     count        mean        std   min     50%    max
# Churn
# 0                  2850.0  200.133193  51.105032  23.2  200.25  395.0
# 1                   483.0  205.231677  47.132825  47.4  204.80  354.9

# %%
dataframe.groupby(by='Churn')[columns_to_show].agg(['mean','std','min','max','var'])
# Out:
#       Total day minutes                                     Total eve minutes  \
#                    mean        std  min    max          var              mean
# Churn
# 0            175.175754  50.181655  0.0  315.6  2518.198517        199.043298
# 1            206.914079  68.997792  0.0  350.8  4760.695237        212.410145
#
#                                            Total night minutes             \
#              std   min    max          var                mean        std
# Churn
# 0      50.292175   0.0  361.8  2529.302828          200.133193  51.105032
# 1      51.728910  70.9  363.7  2675.880084          205.231677  47.132825
#
#
#         min    max          var
# Churn
# 0      23.2  395.0  2611.724331
# 1      47.4  354.9  2221.503165

# %%
pd.crosstab(dataframe['Churn'],dataframe['International plan'])
# Out:
# International plan  False  True
# Churn
# 0                    2664    186
# 1                     346    137

# %%
pd.crosstab(dataframe['Churn'],dataframe['Voice mail plan'],normalize=True)
# Out:
# Voice mail plan     False     True
# Churn
# 0                0.602460  0.252625
# 1                0.120912  0.024002

# %%
dataframe.pivot_table(columns_to_show,["Churn"],aggfunc=["std","mean"])
# Out:
#                     std                                        \
#       Total day minutes Total eve minutes Total night minutes
# Churn
# 0             50.181655         50.292175           51.105032
# 1             68.997792         51.728910           47.132825
#
#                    mean
#       Total day minutes Total eve minutes Total night minutes
# Churn
# 0            175.175754        199.043298          200.133193
# 1            206.914079        212.410145          205.231677

# %%
dataframe.groupby(by='Churn')[columns_to_show].agg(["std","mean"])
# Out:
#       Total day minutes             Total eve minutes              \
#                     std        mean               std        mean
# Churn
# 0             50.181655  175.175754         50.292175  199.043298
# 1             68.997792  206.914079         51.728910  212.410145
#
#       Total night minutes
#                       std        mean
# Churn
# 0               51.105032  200.133193
# 1               47.132825  205.231677

# %%
dataframe['Total_charge']=dataframe['Total day charge']+dataframe['Total eve charge']+dataframe['Total night charge']

# %%
dataframe.drop(['Total_charge'],axis=1,inplace=True)

# %%
dataframe.head(5)
# Out:
#      State  Account length  Area code  International plan  Voice mail plan  \
# 845     FL             144        415               False             True
# 2716    WV             137        510               False             True
# 2887    OR             134        415               False             True
# 1596    AR              63        510               False             True
# 277     SD             144        408               False             True
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 845                      51              283.9               98
# 2716                     50              186.5               94
# 2887                     50              208.8              130
# 1596                     49              214.9               86
# 277                      48              189.8               96
#
#       Total day charge  Total eve minutes  ...  Total eve charge  \
# ...

# %%
pd.crosstab(dataframe['Churn'],dataframe['International plan'],margins=True)
# Out:
# International plan  False  True   All
# Churn
# 0                    2664   186  2850
# 1                     346   137   483
# All                  3010   323  3333
